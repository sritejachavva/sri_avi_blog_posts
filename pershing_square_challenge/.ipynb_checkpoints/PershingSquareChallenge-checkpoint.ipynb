# %% [markdown]
# # This notebook will be comprised of 3 parts
# - Part 1 - Import all pershing square finalist predictions from past 5 years as well as their current stock trends
# - Part 2 - Compare the performance of this winners against major indexes and see if we'd be better off listening to winners
# - Part 3 - Look at some reasons why winners may not have performed against expectations

# %%
### Part 1 -- Importing prediction from google docs

# %%
import numpy as np
import pandas as pd
import os
from datetime import datetime, timedelta
import yfinance as yf
import matplotlib.pyplot as plt
import chart_studio.plotly as py
import plotly.express as px
import plotly.graph_objects as go
current_directory = os.getcwd()
print(current_directory) 
pd.set_option('display.max_rows', 500)
# Out:
# /Users/srite/repos/sri_avi_blog_posts/pershing_square_challenge

# %%
predictions = pd.read_csv('pershing_square_predictions.csv')
predictions['presentation_date'] = pd.to_datetime(predictions['presentation_date'])
predictions.head(20)
# Out:
#     competition_year ticker                      stock_name  base_3  bull_3  \
# 0               2019   ARMK                         Aramark   57.70   81.20
# 1               2019    KMX                          Carmax  149.00  234.00
# 2               2019    DOL                       Dollarama   57.00   75.00
# 3               2019   SERV            Servicemaster Global   78.00     NaN
# 4               2019   USFD                        US Foods   68.85   87.04
# 5               2020    BLL                Ball Corporation     NaN     NaN
# 6               2020     BR  Broadridge Financial Solutions  174.00     NaN
# 7               2020   EPAM                    EPAM Systems     NaN     NaN
# 8               2020    SYY                           Sysco  103.00     NaN
# 9               2020   VRSK                Verisk Analytics  222.00     NaN
# 10              2021   ANGI                            Angi     NaN     NaN
# 11              2021   AVLR                         Avalara     NaN     NaN
# 12              2021     BL                       Blackline     NaN     NaN
# 13              2021    DLB                           Dolby     NaN     NaN
# 14              2021   PEGA                     Pegasystems     NaN     NaN
# 15              2022   CARG                        Cargurus     NaN     NaN
# 16              2022    GAW                  Games Workshop     NaN     NaN
# 17              2022   PGNY                         Progyny     NaN     NaN
# 18              2022   PYPL                          Paypal  232.00     NaN
# 19              2022   TNDM                          Tandem     NaN     NaN
#
#     base_4  bull_4  base_5  bull_5  base_10  bull_10  short_base_9  \
# 0      NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 1      NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 2      NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 3      NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 4      NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 5    115.0     NaN     NaN     NaN      NaN      NaN           NaN
# 6      NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 7    415.0     NaN     NaN     NaN      NaN      NaN           NaN
# 8      NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 9      NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 10     NaN     NaN   45.26     NaN      NaN      NaN           NaN
# 11     NaN     NaN     NaN     NaN    850.0      NaN           NaN
# 12     NaN     NaN  322.00     NaN      NaN      NaN           NaN
# 13     NaN     NaN  205.00     NaN      NaN      NaN           NaN
# 14     NaN     NaN  310.00     NaN      NaN      NaN           NaN
# 15     NaN     NaN  107.84     NaN      NaN      NaN           NaN
# 16     NaN     NaN  182.51     NaN      NaN      NaN           NaN
# 17     NaN     NaN     NaN     NaN      NaN      NaN          21.0
# 18     NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 19     NaN     NaN  285.00     NaN      NaN      NaN           NaN
#
#     short_bull_9  presentation_price  team_rank presentation_date
# 0            NaN               31.00        2.0        2019-04-30
# 1            NaN               75.94        NaN        2019-04-30
# 2            NaN               40.26        1.0        2019-04-30
# 3            NaN               49.05        NaN        2019-04-30
# 4            NaN               37.00        NaN        2019-04-30
# 5            NaN               67.00        NaN        2020-04-30
# 6            NaN              111.54        NaN        2020-04-30
# 7            NaN              196.18        1.0        2020-04-30
# 8            NaN               55.84        2.0        2020-04-30
# 9            NaN              152.00        NaN        2020-04-30
# 10           NaN               17.03        NaN        2021-04-14
# 11           NaN              142.56        NaN        2021-04-14
# 12           NaN              111.00        NaN        2021-04-14
# 13           NaN              102.14        NaN        2021-04-14
# 14           NaN              129.00        NaN        2021-04-14
# 15           NaN               35.34        2.0        2022-04-26
# 16           NaN               73.35        NaN        2022-04-26
# 17           NaN               40.38        1.0        2022-04-26
# 18           NaN               83.70        NaN        2022-04-26
# 19           NaN              100.61        NaN        2022-04-26

# %%
predictions['projection_date'] = '';

predictions.loc[predictions['base_3'].notnull(),'projection_date'] = predictions['presentation_date']  + pd.offsets.DateOffset(years=3)
predictions.loc[predictions['base_4'].notnull(),'projection_date'] = predictions['presentation_date']  + pd.offsets.DateOffset(years=4)
predictions.loc[predictions['base_5'].notnull(),'projection_date'] = predictions['presentation_date']  + pd.offsets.DateOffset(years=5)
#predictions.loc[predictions['base_10'].notnull(),'projection_date'] = predictions['presentation_date']  + timedelta(years=10)
predictions['projection_date'] = pd.to_datetime(predictions['projection_date'])

predictions.head(10)
# Out:
#    competition_year ticker                      stock_name  base_3  bull_3  \
# 0              2019   ARMK                         Aramark   57.70   81.20
# 1              2019    KMX                          Carmax  149.00  234.00
# 2              2019    DOL                       Dollarama   57.00   75.00
# 3              2019   SERV            Servicemaster Global   78.00     NaN
# 4              2019   USFD                        US Foods   68.85   87.04
# 5              2020    BLL                Ball Corporation     NaN     NaN
# 6              2020     BR  Broadridge Financial Solutions  174.00     NaN
# 7              2020   EPAM                    EPAM Systems     NaN     NaN
# 8              2020    SYY                           Sysco  103.00     NaN
# 9              2020   VRSK                Verisk Analytics  222.00     NaN
#
#    base_4  bull_4  base_5  bull_5  base_10  bull_10  short_base_9  \
# 0     NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 1     NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 2     NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 3     NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 4     NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 5   115.0     NaN     NaN     NaN      NaN      NaN           NaN
# 6     NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 7   415.0     NaN     NaN     NaN      NaN      NaN           NaN
# 8     NaN     NaN     NaN     NaN      NaN      NaN           NaN
# 9     NaN     NaN     NaN     NaN      NaN      NaN           NaN
#
#    short_bull_9  presentation_price  team_rank presentation_date  \
# 0           NaN               31.00        2.0        2019-04-30
# 1           NaN               75.94        NaN        2019-04-30
# 2           NaN               40.26        1.0        2019-04-30
# 3           NaN               49.05        NaN        2019-04-30
# 4           NaN               37.00        NaN        2019-04-30
# 5           NaN               67.00        NaN        2020-04-30
# 6           NaN              111.54        NaN        2020-04-30
# 7           NaN              196.18        1.0        2020-04-30
# 8           NaN               55.84        2.0        2020-04-30
# 9           NaN              152.00        NaN        2020-04-30
#
#   projection_date
# 0      2022-04-30
# 1      2022-04-30
# 2      2022-04-30
# 3      2022-04-30
# 4      2022-04-30
# 5      2024-04-30
# 6      2023-04-30
# 7      2024-04-30
# 8      2023-04-30
# 9      2023-04-30

# %%
### create actuals dataframe

def fetch_stock_data(ticker, start_date, end_date):
    data = yf.download(ticker, start=start_date, end=end_date)
    return data
stock_data = [];

for index, row in predictions.iterrows():
    ticker = row['ticker']
    stock_name = row['stock_name']
    team_rank = row['team_rank']
    start_date = row['presentation_date']
    end_date = row['projection_date']
    reported_presentation_day_price = row['presentation_price']
    presentation_year = row['competition_year']


    data_temp = fetch_stock_data(ticker, start_date, end_date)
    data_temp['ticker'] = ticker
    data_temp['stock_name'] = stock_name
    data_temp['team_rank'] = team_rank;
    data_temp['presentation_year'] = presentation_year
    data_temp['reported_presentation_day_price'] = reported_presentation_day_price

    
    
    stock_data.append(data_temp)

    
stock_data = pd.concat(stock_data)
stock_data = stock_data.reset_index()
predictions.dtypes
#for stock in predictions['ticker']:
#    print(stock)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 26
#      21     data_temp['presentation_year'] = presentation_year
#      22     data_temp['reported_presentation_day_price'] = reported_presentation_day_price
# ---> 26     stock_data.append(data_temp)
#      29 stock_data = pd.concat(stock_data)
#      30 stock_data = stock_data.reset_index()
#
# NameError: name 'stock_data' is not defined
